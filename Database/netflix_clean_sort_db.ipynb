# %%
# Add pandas as dependency

import pandas as pd
import psycopg2
import os
# import packages

import pandas as pd
from sqlalchemy import create_engine

# %%
db_password = "Matias1120"

# %%
# Files to load

netflix_data_to_load = "Resources/n_movies.csv"

# %%
# Read the data and store it in Pandas DataFrame

netflix_data_df = pd.read_csv(netflix_data_to_load)

netflix_data_df.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
# Determine if there is any missing values in data

netflix_data_df.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
# Drop the NaNs

netflix_data_df.dropna()
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
print(type(netflix_data_df.year[0]))
# Out:
# <class 'str'>

# %%
# endswith pattern

#print(netflix_data_df['year'].str.endswith('-'))

netflix_data_df['year'] = netflix_data_df['year'].str.replace('(', '')

netflix_data_df
# Out:
# C:\Users\Valentin\AppData\Local\Temp\ipykernel_32636\3130468549.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace('(', '')
#                        title        year certificate duration  \
# 0                  Cobra Kai     2018– )       TV-14   30 min
# 1                  The Crown     2016– )       TV-MA   58 min
# 2           Better Call Saul  2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     2022– )       TV-MA   24 min
# ...                      ...         ...         ...      ...
# 9952          The Imperfects     2022– )       TV-MA   45 min
# 9953        The Walking Dead  2010–2022)       TV-MA   44 min
# 9954               The Crown     2016– )       TV-MA   58 min
# ...

# %%
netflix_data_df['year'] = netflix_data_df['year'].str.replace(')', '')

netflix_data_df.head()
# Out:
# C:\Users\Valentin\AppData\Local\Temp\ipykernel_32636\1997076803.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace(')', '')
#                     title       year certificate duration  \
# 0               Cobra Kai     2018–        TV-14   30 min
# 1               The Crown     2016–        TV-MA   58 min
# 2        Better Call Saul  2015–2022       TV-MA   46 min
# 3           Devil in Ohio       2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     2022–        TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
# ...

# %%
netflix_data_df['year released'] = netflix_data_df['year'].str[0:4]

netflix_data_df['year released']
# Out:
# 0       2018
# 1       2016
# 2       2015
# 3       2022
# 4       2022
#         ...
# 9952    2022
# 9953    2010
# 9954    2016
# 9955    2005
# 9956    2022
# Name: year released, Length: 9957, dtype: object

# %%
netflix_data_df = netflix_data_df[['title', 'year released', 'certificate', 'duration', 'genre', 'rating','description','stars', 'votes']]

netflix_data_df.head()
# Out:
#                     title year released certificate duration  \
# 0               Cobra Kai          2018       TV-14   30 min
# 1               The Crown          2016       TV-MA   58 min
# 2        Better Call Saul          2015       TV-MA   46 min
# 3           Devil in Ohio          2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners          2022       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
netflix_data_df.isna().sum()
# Out:
# title               0
# year released     527
# certificate      3453
# duration         2036
# genre              73
# rating           1173
# description         0
# stars               0
# votes            1173
# dtype: int64

# %%
netflix_data_df_drop = netflix_data_df.dropna()

netflix_data_df_drop
# Out:
#                        title year released certificate duration  \
# 0                  Cobra Kai          2018       TV-14   30 min
# 1                  The Crown          2016       TV-MA   58 min
# 2           Better Call Saul          2015       TV-MA   46 min
# 3              Devil in Ohio          2022       TV-MA  356 min
# 4     Cyberpunk: Edgerunners          2022       TV-MA   24 min
# ...                      ...           ...         ...      ...
# 9952          The Imperfects          2022       TV-MA   45 min
# 9953        The Walking Dead          2010       TV-MA   44 min
# 9954               The Crown          2016       TV-MA   58 min
# 9955            Supernatural          2005       TV-14   44 min
# 9956           Devil in Ohio          2022       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
netflix_data_df_sort = netflix_data_df_drop.sort_values(by = ['year released'])

netflix_data_df_sort
# Out:
#                          title year released certificate duration  \
# 1445                  Scarface          1932          PG   93 min
# 1119                     Dumbo          1941           G   64 min
# 4072  Nazi Concentration Camps          1945   Not Rated   59 min
# 6348   Know Your Enemy - Japan          1945   Not Rated   63 min
# 4627          Along Came Jones          1945    Approved   90 min
# ...                        ...           ...         ...      ...
# 3525                     Mercy          IV 2       TV-MA   90 min
# 5570             The Awakening          V 20   Not Rated   83 min
# 5076                       Joy          V 20       TV-MA   99 min
# 983                       Prey          VI 2       TV-MA   87 min
# 3836       At the Devil's Door          VI 2   Not Rated   91 min
#
#                             genre  rating  \
# 1445         Action, Crime, Drama     7.7
# 1119  Animation, Adventure, Drama     7.2
# 4072         Documentary, History     8.3
# ...

# %%
netflix_data_df_sort.reset_index()
# Out:
#       index                     title year released certificate duration  \
# 0      1445                  Scarface          1932          PG   93 min
# 1      1119                     Dumbo          1941           G   64 min
# 2      4072  Nazi Concentration Camps          1945   Not Rated   59 min
# 3      6348   Know Your Enemy - Japan          1945   Not Rated   63 min
# 4      4627          Along Came Jones          1945    Approved   90 min
# ...     ...                       ...           ...         ...      ...
# 5749   3525                     Mercy          IV 2       TV-MA   90 min
# 5750   5570             The Awakening          V 20   Not Rated   83 min
# 5751   5076                       Joy          V 20       TV-MA   99 min
# 5752    983                      Prey          VI 2       TV-MA   87 min
# 5753   3836       At the Devil's Door          VI 2   Not Rated   91 min
#
#                             genre  rating  \
# 0            Action, Crime, Drama     7.7
# ...

# %%
netflix_data_df_sort.drop(netflix_data_df_sort.tail(243).index,
                                                inplace = True)

# %%
netflix_data_df_sort['year released'].value_counts()
# Out:
# 2020    681
# 2019    622
# 2018    602
# 2021    565
# 2017    452
#        ...
# 1964      1
# 1958      1
# 1957      1
# 1947      1
# 1985      1
# Name: year released, Length: 76, dtype: int64

# %%
netflix_data_df_sort.to_csv("Resources/netflix_clean_sort.csv", index = False, header = True)

# %%
netflix_data_df_sort.head()
# Out:
#                          title year released certificate duration  \
# 1445                  Scarface          1932          PG   93 min
# 1119                     Dumbo          1941           G   64 min
# 4072  Nazi Concentration Camps          1945   Not Rated   59 min
# 6348   Know Your Enemy - Japan          1945   Not Rated   63 min
# 4627          Along Came Jones          1945    Approved   90 min
#
#                             genre  rating  \
# 1445         Action, Crime, Drama     7.7
# 1119  Animation, Adventure, Drama     7.2
# 4072         Documentary, History     8.3
# 6348    Documentary, History, War     6.0
# 4627     Comedy, Romance, Western     6.4
#
#                                             description  \
# 1445  An ambitious and nearly insane violent gangste...
# 1119  Ridiculed because of his enormous ears, a youn...
# 4072  Produced and presented as evidence at the Nure...
# 6348  A comprehensive look at the war in the Pacific...
# ...

# %%
#Took the data to excel to make a few more adjustments and cleaning
#will import it back in
netflix_data_load = "Resources/netflix_clean_ex.csv"

# %%
netflix_data_ex = pd.read_csv(netflix_data_load)

netflix_data_ex.head()
# Out:
#   show_id                     title  year released certificate  duration_min  \
# 0      S1                  Scarface           1932          PG            93
# 1      S2                     Dumbo           1941           G            64
# 2      S3  Nazi Concentration Camps           1945   Not Rated            59
# 3      S4   Know Your Enemy - Japan           1945   Not Rated            63
# 4      S5          Along Came Jones           1945    Approved            90
#
#          genre  rating                                        description  \
# 0       Action     7.7  An ambitious and nearly insane violent gangste...
# 1    Animation     7.2  Ridiculed because of his enormous ears, a youn...
# 2  Documentary     8.3  Produced and presented as evidence at the Nure...
# 3  Documentary     6.0  A comprehensive look at the war in the Pacific...
# 4       Comedy     6.4  A good-natured saddle tramp traveling with his...
#
# ...

# %%
#break into 2 tables
# first table all descriptive info
netflix_descriptive_data = netflix_data_ex[['show_id','title', 'year released', 'certificate', 'duration_min', 'genre','description','stars' ]]

netflix_descriptive_data.head()
# Out:
#   show_id                     title  year released certificate  duration_min  \
# 0      S1                  Scarface           1932          PG            93
# 1      S2                     Dumbo           1941           G            64
# 2      S3  Nazi Concentration Camps           1945   Not Rated            59
# 3      S4   Know Your Enemy - Japan           1945   Not Rated            63
# 4      S5          Along Came Jones           1945    Approved            90
#
#          genre                                        description  \
# 0       Action  An ambitious and nearly insane violent gangste...
# 1    Animation  Ridiculed because of his enormous ears, a youn...
# 2  Documentary  Produced and presented as evidence at the Nure...
# 3  Documentary  A comprehensive look at the war in the Pacific...
# 4       Comedy  A good-natured saddle tramp traveling with his...
#
#                                                stars
# ...

# %%
netflix_rating_data = netflix_data_ex[['show_id','title', 'genre', 'rating','votes']]

netflix_rating_data.head()
# Out:
#   show_id                     title        genre  rating    votes
# 0      S1                  Scarface       Action     7.7   28,107
# 1      S2                     Dumbo    Animation     7.2  131,896
# 2      S3  Nazi Concentration Camps  Documentary     8.3    1,481
# 3      S4   Know Your Enemy - Japan  Documentary     6.0      800
# 4      S5          Along Came Jones       Comedy     6.4    2,163

# %%
netflix_data_final = "Resources/final_clean_data.csv"

# %%
final_clean_data = pd.read_csv(netflix_data_final)

final_clean_data.head()
# Out:
#                       title  year released certificate  duration_min  \
# 0                  Scarface           1932          PG            93
# 1                     Dumbo           1941           G            64
# 2  Nazi Concentration Camps           1945   Not Rated            59
# 3   Know Your Enemy - Japan           1945   Not Rated            63
# 4          Along Came Jones           1945    Approved            90
#
#         genre   rating    votes  age
# 0       Action     7.7   28,107   90
# 1    Animation     7.2  131,896   81
# 2  Documentary     8.3    1,481   77
# 3  Documentary     6.0      800   77
# 4       Comedy     6.4    2,163   77

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Netflix_movie_data"

# %%
engine = create_engine(db_string)

# %%
netflix_rating_data.to_sql(name='Netflix_Rating_data', con=engine)
# Out:
# 511

# %%
netflix_descriptive_data.to_sql(name='Netflix_Descriptive_data', con=engine)
# Out:
# 511

# %%
final_clean_data.to_sql(name='final_clean_data', con=engine)
# Out:
#      show_id                      title  year released certificate  \
# 0         S1                   Scarface           1932          PG
# 1         S2                      Dumbo           1941           G
# 2         S3   Nazi Concentration Camps           1945   Not Rated
# 3         S4    Know Your Enemy - Japan           1945   Not Rated
# 4         S5           Along Came Jones           1945    Approved
# ...      ...                        ...            ...         ...
# 5506   S5507            Hurts Like Hell           2022       TV-MA
# 5507   S5508           Toolsidas Junior           2022       TV-14
# 5508   S5509                Incantation           2022       TV-MA
# 5509   S5510  Fortune Seller: A TV Scam           2022       TV-14
# 5510   S5511               Heartstopper           2022       TV-14
#
#       duration_min        genre  rating  \
# 0               93       Action     7.7
# 1               64    Animation     7.2
# ...

# %%
  
def get_connection():
    try:
        return psycopg2.connect(
            database="postgres",
            user="postgres",
            password= db_password,
            host="127.0.0.1",
            port=5432,
        )
    except:
        return False
  
conn = get_connection()
  
if conn:
    print("Connection to the PostgreSQL established successfully.")
else:
    print("Connection to the PostgreSQL encountered and error.")

# %%
# This program uses fetchall()
# to query all the records from a table
  
# GET THE CONNECTION OBJECT
conn = get_connection()
  
# CREATE A CURSOR USING THE CONNECTION OBJECT
curr = conn.cursor()
  
# EXECUTE THE SQL QUERY
curr.execute("SELECT * FROM students;")
  
# FETCH ALL THE ROWS FROM THE CURSOR
data = curr.fetchall()
  
# PRINT THE RECORDS
for row in data:
    print(row)
  
# CLOSE THE CONNECTION
conn.close()
