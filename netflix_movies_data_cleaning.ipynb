# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # Ploting library
# %matplotlib inline

# %%
# Reading data 

netflix_data = pd.read_csv('n_movies.csv')
netflix_data
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
netflix_1Data=netflix_data[['title','year','certificate','duration','genre','rating','votes']]
netflix_1Data.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating    votes
# 0         Action, Comedy, Drama     8.5  177,031
# 1     Biography, Drama, History     8.7  199,885
# 2                  Crime, Drama     8.9  501,384
# 3        Drama, Horror, Mystery     5.9    9,773
# 4  Animation, Action, Adventure     8.6   15,413

# %%
netflix_1Data
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating    votes
# 0            Action, Comedy, Drama     8.5  177,031
# 1        Biography, Drama, History     8.7  199,885
# ...

# %%
netflix_1Data.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# votes          1173
# dtype: int64

# %%
#Dropping Nulls from data
netflix_1Data= netflix_1Data.dropna()

#checking if any nulls are left
netflix_1Data.isnull().sum()
# Out:
# title          0
# year           0
# certificate    0
# duration       0
# genre          0
# rating         0
# votes          0
# dtype: int64

# %%
netflix_1Data.shape
# Out:
# (5754, 7)

# %%
netflix_1Data
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating    votes
# 0            Action, Comedy, Drama     8.5  177,031
# 1        Biography, Drama, History     8.7  199,885
# ...

# %%
# Sorting movies by highest rating descending
Rating_sorted_movies = netflix_1Data.sort_values('rating', ascending=False)
Rating_sorted_movies
# Out:
#                                  title         year certificate duration  \
# 9444                   BoJack Horseman  (2014–2020)       TV-MA   26 min
# 8161        Avatar: The Last Airbender  (2005–2008)       TV-Y7   25 min
# 8259                            Dexter  (2006–2013)       TV-MA   56 min
# 8557          JoJo's Bizarre Adventure     (2012– )       TV-MA   25 min
# 9578                   Stranger Things     (2016– )       TV-14   98 min
# ...                                ...          ...         ...      ...
# 3612                    The Hype House     (2022– )       TV-MA   36 min
# 3357  Thomas & Friends: All Engines Go     (2021– )        TV-Y   30 min
# 4987                Way of the Vampire       (2005)           R   82 min
# 6033       Hajwala: The Missing Engine       (2016)       PG-13   96 min
# 6633                       Defcon 2012       (2010)   Not Rated   92 min
#
#                              genre  rating   votes
# ...

# %%
vote_sorted_movies = netflix_1Data.copy()
vote_sorted_movies.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating    votes
# 0         Action, Comedy, Drama     8.5  177,031
# 1     Biography, Drama, History     8.7  199,885
# 2                  Crime, Drama     8.9  501,384
# 3        Drama, Horror, Mystery     5.9    9,773
# 4  Animation, Action, Adventure     8.6   15,413

# %%
vote_sorted_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5754 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        5754 non-null   object
#  1   year         5754 non-null   object
#  2   certificate  5754 non-null   object
#  3   duration     5754 non-null   object
#  4   genre        5754 non-null   object
#  5   rating       5754 non-null   float64
#  6   votes        5754 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 359.6+ KB

# %%
# replacing commas in string and converting to float values for easy computation
voted_sorted_movies['votes'] = vote_sorted_movies['votes'].apply(lambda x : x.replace(',',''))
vote_sorted_movies['votes'] = vote_sorted_movies['votes'].apply(lambda x : float(x))
netflix_1Data['votes'] = vote_sorted_movies['votes']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Valentin\Desktop\Final_Project\netflix_movies_data_cleaning.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Valentin/Desktop/Final_Project/netflix_movies_data_cleaning.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # replacing commas in string and converting to float values for easy computation
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Valentin/Desktop/Final_Project/netflix_movies_data_cleaning.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> voted_sorted_movies['votes'] = vote_sorted_movies['votes'].apply(lambda x : x.replace(',',''))
#       <a href='vscode-notebook-cell:/c%3A/Users/Valentin/Desktop/Final_Project/netflix_movies_data_cleaning.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> vote_sorted_movies['votes'] = vote_sorted_movies['votes'].apply(lambda x : float(x))
# ...

# %%
#confirming that values were converted to float
vote_sorted_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5754 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        5754 non-null   object
#  1   year         5754 non-null   object
#  2   certificate  5754 non-null   object
#  3   duration     5754 non-null   object
#  4   genre        5754 non-null   object
#  5   rating       5754 non-null   float64
#  6   votes        5754 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 359.6+ KB

# %%
# Removing unnecessary columns
vote_sorted_movies = vote_sorted_movies.groupby('title').sum()

vote_sorted_movies.head()
# Out:
#                      rating    votes
# title
# #Alive                  6.3  39285.0
# #BlackAF                6.7   4887.0
# #FriendButMarried 2     6.9    317.0
# #FriendsButMarried      6.8    727.0
# #Realityhigh            5.1   6432.0

# %%
#sorting movies by highest rating in descending order by votes
vote_sorted_movies = vote_sorted_movies.sort_values('votes', ascending=False)

vote_sorted_movies
# Out:
#                                                    rating      votes
# title
# The Lord of the Rings: The Fellowship of the Ring    17.6  3688130.0
# Breaking Bad                                         19.0  3662699.0
# Stranger Things                                      86.1  2477471.0
# Friends                                              17.8  1958852.0
# The Walking Dead                                     16.2  1940127.0
# ...                                                   ...        ...
# Inside: The Mob's Bloody Valentine                    6.5        9.0
# Mighty Express: Train Trouble                         5.3        9.0
# Iron Chef: Mexico                                     8.7        8.0
# Shaka Inkosi YamaKhosi                                6.5        8.0
# Chip and Potato: Chip's Holiday                       6.4        8.0
#
# [4413 rows x 2 columns]
