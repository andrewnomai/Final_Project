# %%
# Add pandas as dependency

import pandas as pd

import os

import matplotlib.pyplot as plt

# %%
# Files to load

netflix_data_to_load = "Resources/n_movies.csv"

# %%
# Read the data and store it in Pandas DataFrame

netflix_data_df = pd.read_csv(netflix_data_to_load)

netflix_data_df.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
#                                                stars    votes
# 0  ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...  177,031
# 1  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885
# 2  ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384
# 3  ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,773
# 4  ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...   15,413

# %%
# Determine if there is any missing values in the data

netflix_data_df.count()
# Out:
# title          9957
# year           9430
# certificate    6504
# duration       7921
# genre          9884
# rating         8784
# description    9957
# stars          9957
# votes          8784
# dtype: int64

# %%
# Determine if there is any missing values in data

netflix_data_df.isnull()
# Out:
#       title   year  certificate  duration  genre  rating  description  stars  \
# 0     False  False        False     False  False   False        False  False
# 1     False  False        False     False  False   False        False  False
# 2     False  False        False     False  False   False        False  False
# 3     False  False        False     False  False   False        False  False
# 4     False  False        False     False  False   False        False  False
# ...     ...    ...          ...       ...    ...     ...          ...    ...
# 9952  False  False        False     False  False   False        False  False
# 9953  False  False        False     False  False   False        False  False
# 9954  False  False        False     False  False   False        False  False
# 9955  False  False        False     False  False   False        False  False
# 9956  False  False        False     False  False   False        False  False
#
#       votes
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9952  False
# 9953  False
# 9954  False
# 9955  False
# 9956  False
#
# [9957 rows x 9 columns]

# %%
# Determine if there is any missing values in data

netflix_data_df.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
# Drop the NaNs

netflix_data_df.dropna()
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...                            ...     ...
# 9952      Action, Adventure, Drama     6.3
# 9953       Drama, Horror, Thriller     8.1
# 9954     Biography, Drama, History     8.7
# 9955        Drama, Fantasy, Horror     8.4
# 9956        Drama, Horror, Mystery     5.9
#
#                                             description  \
# 0     Decades after their 1984 All Valley Karate Tou...
# 1     Follows the political rivalries and romance of...
# 2     The trials and tribulations of criminal lawyer...
# 3     When a psychiatrist shelters a mysterious cult...
# 4     A Street Kid trying to survive in a technology...
# ...                                                 ...
# 9952  After an experimental gene therapy turns them ...
# 9953  Sheriff Deputy Rick Grimes wakes up from a com...
# 9954  Follows the political rivalries and romance of...
# 9955  Two brothers follow their father's footsteps a...
# 9956  When a psychiatrist shelters a mysterious cult...
#
#                                                   stars    votes
# 0     ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...  177,031
# 1     ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885
# 2     ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384
# 3     ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,773
# 4     ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...   15,413
# ...                                                 ...      ...
# 9952  ['Morgan Taylor Campbell, ', 'Italia Ricci, ',...    3,130
# 9953  ['Andrew Lincoln, ', 'Norman Reedus, ', 'Melis...  970,067
# 9954  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,898
# 9955  ['Jared Padalecki, ', 'Jensen Ackles, ', 'Jim ...  439,601
# 9956  ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,786
#
# [5754 rows x 9 columns]

# %%
netflix_data_df.dropna().count()
# Out:
# title          5754
# year           5754
# certificate    5754
# duration       5754
# genre          5754
# rating         5754
# description    5754
# stars          5754
# votes          5754
# dtype: int64

# %%
netflix_data_df

# data limitation = votes are not clear on whether they are compiled from year released or votes per year.
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...                            ...     ...
# 9952      Action, Adventure, Drama     6.3
# 9953       Drama, Horror, Thriller     8.1
# 9954     Biography, Drama, History     8.7
# 9955        Drama, Fantasy, Horror     8.4
# 9956        Drama, Horror, Mystery     5.9
#
#                                             description  \
# 0     Decades after their 1984 All Valley Karate Tou...
# 1     Follows the political rivalries and romance of...
# 2     The trials and tribulations of criminal lawyer...
# 3     When a psychiatrist shelters a mysterious cult...
# 4     A Street Kid trying to survive in a technology...
# ...                                                 ...
# 9952  After an experimental gene therapy turns them ...
# 9953  Sheriff Deputy Rick Grimes wakes up from a com...
# 9954  Follows the political rivalries and romance of...
# 9955  Two brothers follow their father's footsteps a...
# 9956  When a psychiatrist shelters a mysterious cult...
#
#                                                   stars    votes
# 0     ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...  177,031
# 1     ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885
# 2     ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384
# 3     ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,773
# 4     ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...   15,413
# ...                                                 ...      ...
# 9952  ['Morgan Taylor Campbell, ', 'Italia Ricci, ',...    3,130
# 9953  ['Andrew Lincoln, ', 'Norman Reedus, ', 'Melis...  970,067
# 9954  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,898
# 9955  ['Jared Padalecki, ', 'Jensen Ackles, ', 'Jim ...  439,601
# 9956  ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,786
#
# [9957 rows x 9 columns]

# %%
netflix_data_df = netflix_data_df[['title','year','certificate','duration','genre','rating','votes']]
netflix_data_df.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating    votes
# 0         Action, Comedy, Drama     8.5  177,031
# 1     Biography, Drama, History     8.7  199,885
# 2                  Crime, Drama     8.9  501,384
# 3        Drama, Horror, Mystery     5.9    9,773
# 4  Animation, Action, Adventure     8.6   15,413

# %%
# checking datatype

print(type(netflix_data_df.year[0]))
# Out:
# <class 'str'>

# %%
# endswith pattern

#print(netflix_data_df['year'].str.endswith('-'))

netflix_data_df['year'] = netflix_data_df['year'].str.replace('(', '')

netflix_data_df


#netflix_year_shorten = netflix_data_df['year'].slice[:5]

#netflix_year_shorten

#netflix_data_df
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_5036\2455076951.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace('(', '')
# C:\Users\andre\AppData\Local\Temp\ipykernel_5036\2455076951.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace('(', '')
#                        title        year certificate duration  \
# 0                  Cobra Kai     2018– )       TV-14   30 min
# 1                  The Crown     2016– )       TV-MA   58 min
# 2           Better Call Saul  2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     2022– )       TV-MA   24 min
# ...                      ...         ...         ...      ...
# 9952          The Imperfects     2022– )       TV-MA   45 min
# 9953        The Walking Dead  2010–2022)       TV-MA   44 min
# 9954               The Crown     2016– )       TV-MA   58 min
# 9955            Supernatural  2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       2022)       TV-MA  356 min
#
#                              genre  rating    votes
# 0            Action, Comedy, Drama     8.5  177,031
# 1        Biography, Drama, History     8.7  199,885
# 2                     Crime, Drama     8.9  501,384
# 3           Drama, Horror, Mystery     5.9    9,773
# 4     Animation, Action, Adventure     8.6   15,413
# ...                            ...     ...      ...
# 9952      Action, Adventure, Drama     6.3    3,130
# 9953       Drama, Horror, Thriller     8.1  970,067
# 9954     Biography, Drama, History     8.7  199,898
# 9955        Drama, Fantasy, Horror     8.4  439,601
# 9956        Drama, Horror, Mystery     5.9    9,786
#
# [9957 rows x 7 columns]

# %%
netflix_data_df['year'] = netflix_data_df['year'].str.replace(')', '')

netflix_data_df.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_5036\1997076803.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace(')', '')
# C:\Users\andre\AppData\Local\Temp\ipykernel_5036\1997076803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_data_df['year'] = netflix_data_df['year'].str.replace(')', '')
#                     title       year certificate duration  \
# 0               Cobra Kai     2018–        TV-14   30 min
# 1               The Crown     2016–        TV-MA   58 min
# 2        Better Call Saul  2015–2022       TV-MA   46 min
# 3           Devil in Ohio       2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     2022–        TV-MA   24 min
#
#                           genre  rating    votes
# 0         Action, Comedy, Drama     8.5  177,031
# 1     Biography, Drama, History     8.7  199,885
# 2                  Crime, Drama     8.9  501,384
# 3        Drama, Horror, Mystery     5.9    9,773
# 4  Animation, Action, Adventure     8.6   15,413

# %%
netflix_data_df['year released'] = netflix_data_df['year'].str[0:4]

netflix_data_df['year released']
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_5036\882925735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_data_df['year released'] = netflix_data_df['year'].str[0:4]
# 0       2018
# 1       2016
# 2       2015
# 3       2022
# 4       2022
#         ...
# 9952    2022
# 9953    2010
# 9954    2016
# 9955    2005
# 9956    2022
# Name: year released, Length: 9957, dtype: object

# %%
netflix_data_df = netflix_data_df[['title', 'year released', 'certificate', 'duration', 'genre', 'rating', 'votes']]

netflix_data_df.head()
# Out:
#                     title year released certificate duration  \
# 0               Cobra Kai          2018       TV-14   30 min
# 1               The Crown          2016       TV-MA   58 min
# 2        Better Call Saul          2015       TV-MA   46 min
# 3           Devil in Ohio          2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners          2022       TV-MA   24 min
#
#                           genre  rating    votes
# 0         Action, Comedy, Drama     8.5  177,031
# 1     Biography, Drama, History     8.7  199,885
# 2                  Crime, Drama     8.9  501,384
# 3        Drama, Horror, Mystery     5.9    9,773
# 4  Animation, Action, Adventure     8.6   15,413

# %%
netflix_data_df.isna().sum()
# Out:
# title               0
# year released     527
# certificate      3453
# duration         2036
# genre              73
# rating           1173
# votes            1173
# dtype: int64

# %%
netflix_data_df_drop = netflix_data_df.dropna()

netflix_data_df_drop
# Out:
#                        title year released certificate duration  \
# 0                  Cobra Kai          2018       TV-14   30 min
# 1                  The Crown          2016       TV-MA   58 min
# 2           Better Call Saul          2015       TV-MA   46 min
# 3              Devil in Ohio          2022       TV-MA  356 min
# 4     Cyberpunk: Edgerunners          2022       TV-MA   24 min
# ...                      ...           ...         ...      ...
# 9952          The Imperfects          2022       TV-MA   45 min
# 9953        The Walking Dead          2010       TV-MA   44 min
# 9954               The Crown          2016       TV-MA   58 min
# 9955            Supernatural          2005       TV-14   44 min
# 9956           Devil in Ohio          2022       TV-MA  356 min
#
#                              genre  rating    votes
# 0            Action, Comedy, Drama     8.5  177,031
# 1        Biography, Drama, History     8.7  199,885
# 2                     Crime, Drama     8.9  501,384
# 3           Drama, Horror, Mystery     5.9    9,773
# 4     Animation, Action, Adventure     8.6   15,413
# ...                            ...     ...      ...
# 9952      Action, Adventure, Drama     6.3    3,130
# 9953       Drama, Horror, Thriller     8.1  970,067
# 9954     Biography, Drama, History     8.7  199,898
# 9955        Drama, Fantasy, Horror     8.4  439,601
# 9956        Drama, Horror, Mystery     5.9    9,786
#
# [5754 rows x 7 columns]

# %%
netflix_data_df_sort = netflix_data_df_drop.sort_values(by = ['year released'])

netflix_data_df_sort
# Out:
#                          title year released certificate duration  \
# 1445                  Scarface          1932          PG   93 min
# 1119                     Dumbo          1941           G   64 min
# 4072  Nazi Concentration Camps          1945   Not Rated   59 min
# 6348   Know Your Enemy - Japan          1945   Not Rated   63 min
# 4627          Along Came Jones          1945    Approved   90 min
# ...                        ...           ...         ...      ...
# 3525                     Mercy          IV 2       TV-MA   90 min
# 5570             The Awakening          V 20   Not Rated   83 min
# 5076                       Joy          V 20       TV-MA   99 min
# 983                       Prey          VI 2       TV-MA   87 min
# 3836       At the Devil's Door          VI 2   Not Rated   91 min
#
#                             genre  rating    votes
# 1445         Action, Crime, Drama     7.7   28,107
# 1119  Animation, Adventure, Drama     7.2  131,896
# 4072         Documentary, History     8.3    1,481
# 6348    Documentary, History, War     6.0      800
# 4627     Comedy, Romance, Western     6.4    2,163
# ...                           ...     ...      ...
# 3525     Drama, Mystery, Thriller     4.1    3,519
# 5570             Horror, Thriller     2.5      155
# 5076                        Drama     6.6    1,328
# 983    Adventure, Drama, Thriller     4.3    7,747
# 3836                       Horror     4.7    7,184
#
# [5754 rows x 7 columns]

# %%
netflix_data_df_sort.reset_index()
# Out:
#       index                     title year released certificate duration  \
# 0      1445                  Scarface          1932          PG   93 min
# 1      1119                     Dumbo          1941           G   64 min
# 2      4072  Nazi Concentration Camps          1945   Not Rated   59 min
# 3      6348   Know Your Enemy - Japan          1945   Not Rated   63 min
# 4      4627          Along Came Jones          1945    Approved   90 min
# ...     ...                       ...           ...         ...      ...
# 5749   3525                     Mercy          IV 2       TV-MA   90 min
# 5750   5570             The Awakening          V 20   Not Rated   83 min
# 5751   5076                       Joy          V 20       TV-MA   99 min
# 5752    983                      Prey          VI 2       TV-MA   87 min
# 5753   3836       At the Devil's Door          VI 2   Not Rated   91 min
#
#                             genre  rating    votes
# 0            Action, Crime, Drama     7.7   28,107
# 1     Animation, Adventure, Drama     7.2  131,896
# 2            Documentary, History     8.3    1,481
# 3       Documentary, History, War     6.0      800
# 4        Comedy, Romance, Western     6.4    2,163
# ...                           ...     ...      ...
# 5749     Drama, Mystery, Thriller     4.1    3,519
# 5750             Horror, Thriller     2.5      155
# 5751                        Drama     6.6    1,328
# 5752   Adventure, Drama, Thriller     4.3    7,747
# 5753                       Horror     4.7    7,184
#
# [5754 rows x 8 columns]

# %%
netflix_data_df_sort.drop(netflix_data_df_sort.tail(243).index,
                                                inplace = True)

# %%
netflix_data_df_sort
# Out:
#                           title year released certificate duration  \
# 1445                   Scarface          1932          PG   93 min
# 1119                      Dumbo          1941           G   64 min
# 4072   Nazi Concentration Camps          1945   Not Rated   59 min
# 6348    Know Your Enemy - Japan          1945   Not Rated   63 min
# 4627           Along Came Jones          1945    Approved   90 min
# ...                         ...           ...         ...      ...
# 3668            Hurts Like Hell          2022       TV-MA  200 min
# 3551           Toolsidas Junior          2022       TV-14  132 min
# 296                 Incantation          2022       TV-MA  110 min
# 3711  Fortune Seller: A TV Scam          2022       TV-14   45 min
# 306                Heartstopper          2022       TV-14   30 min
#
#                               genre  rating    votes
# 1445           Action, Crime, Drama     7.7   28,107
# 1119    Animation, Adventure, Drama     7.2  131,896
# 4072           Documentary, History     8.3    1,481
# 6348      Documentary, History, War     6.0      800
# 4627       Comedy, Romance, Western     6.4    2,163
# ...                             ...     ...      ...
# 3668        Biography, Drama, Sport     7.4      247
# 3551           Drama, Family, Sport     7.4    2,162
# 296                 Horror, Mystery     6.2   11,424
# 3711  Documentary, Biography, Crime     6.4       69
# 306                  Drama, Romance     8.7   49,420
#
# [5511 rows x 7 columns]

# %%
netflix_data_df_sort['year released'] = netflix_data_df_sort['year released'].astype('int')

# %%
new_netflix_df = netflix_data_df_sort.loc[netflix_data_df_sort['year released']>2011]
new_netflix_df = new_netflix_df.groupby(['year released'])['rating'].mean()


new_netflix_df.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='year released'>

# %%
top_10_movies = netflix_data_df_sort.sort_values("rating", ascending = False).head(10)

top_10_movies
# Out:
#                            title  year released certificate duration  \
# 9444             BoJack Horseman           2014       TV-MA   26 min
# 9578             Stranger Things           2016       TV-14   98 min
# 8259                      Dexter           2006       TV-MA   56 min
# 8557    JoJo's Bizarre Adventure           2012       TV-MA   25 min
# 8907  Avatar: The Last Airbender           2005       TV-Y7   24 min
# 8161  Avatar: The Last Airbender           2005       TV-Y7   25 min
# 8819                        Dark           2017       TV-MA   54 min
# 8044  Avatar: The Last Airbender           2005       TV-Y7   25 min
# 9608              Anne with an E           2017       TV-PG   44 min
# 9951                Breaking Bad           2008       TV-MA   49 min
#
#                              genre  rating      votes
# 9444      Animation, Comedy, Drama     9.9     16,066
# 9578        Drama, Fantasy, Horror     9.6     36,276
# 8259         Crime, Drama, Mystery     9.6     10,604
# 8557  Animation, Action, Adventure     9.6      1,442
# 8907  Animation, Action, Adventure     9.6      3,953
# 8161  Animation, Action, Adventure     9.6      5,221
# 8819         Crime, Drama, Mystery     9.5     14,007
# 8044  Animation, Action, Adventure     9.5      5,383
# 9608                 Drama, Family     9.5      2,488
# 9951        Crime, Drama, Thriller     9.5  1,831,359

# %%
plt.figure(figsize = (8, 8))

plt.barh(top_10_movies["title"], top_10_movies["rating"], color = "cornflowerblue")
# Out:
# <BarContainer object of 10 artists>

# %%
netflix_data_df_sort['rating category'] = pd.cut(x = netflix_data_df_sort['rating'],
                                          bins = [1, 4, 7, 10],
                                          labels = ['Bad', 'Good', 'Excellent'])
netflix_data_df_sort

# %%
netflix_data_df_sort.drop('title', axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = le.fit

# %%
X = netflix_data_df_sort.drop(['rating', 'rating category'], axis = 1).values
y = netflix_data_df_sort['rating category'].values

# %%
# split the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
